# %%
conda install pyyaml
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pprint
import json
import pyyaml
dct_arr = [
  {'Name': 'John', 'Age': '23', 'Country': 'USA'},
  {'Name': 'Jose', 'Age': '44', 'Country': 'Spain'},
  {'Name': 'Anne', 'Age': '29', 'Country': 'UK'},
  {'Name': 'Lee', 'Age': '35', 'Country': 'Japan'}
]

pprint.pprint({})
print(json.dumps({},sort_keys=False, indent=1))
print(yaml.dump({}, sort_keys=False, default_flow_style=False))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [32], in <cell line: 3>()
#       1 import pprint
#       2 import json
# ----> 3 import pyyaml
#       4 dct_arr = [
#       5   {'Name': 'John', 'Age': '23', 'Country': 'USA'},
#       6   {'Name': 'Jose', 'Age': '44', 'Country': 'Spain'},
#       7   {'Name': 'Anne', 'Age': '29', 'Country': 'UK'},
#       8   {'Name': 'Lee', 'Age': '35', 'Country': 'Japan'}
#       9 ]
#      11 pprint.pprint(dct_arr)
#
# ModuleNotFoundError: No module named 'pyyaml'

# %%
t= (2,5)
list(t)
tuple(list(t))
list((2,5))
tuple([2,5])
# Out:
# (2, 5)

# %%
bacon =[3.14, 'cat', 11, 'cat', True]
bacon.index('cat')
# Out:
# 1

# %%
bacon.append(99)
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %%
bacon.remove('cat')

# %%
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %%
bacon.insert()
bacon.append

# %%
'Hello, world!'[3:]
# Out:
# 'lo, world!'

# %%
'Hello'.upper().lower()
# Out:
# 'hello'

# %%
# 'Remember, remember, the fifth of July.'.split()
'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %%
'         Hello    '.rstrip()
# Out:
# '         Hello'

# %%
import re
s = "string of my name and adddress is poooooone"

# %%
patt = re.compile('o{1,6}')
re.findall(patt,s)
# Out:
# ['o', 'oooooo']

# %%
pip install pypi
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Created wheel for pypi: filename=pypi-2.1-py3-none-any.whl size=1352 sha256=67f513cba3bfc94eb8ea5e5e66757597dfe07d25f83dda1234d7c75f0a98d20d
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\de\52\e9\d760a5e0e4b77d30df3da4e71e10451443393d77c2b3d0ed8c
# Successfully built pypi
# ...

# %%
 Create a programme that searches a folder tree for files with a certain file extension 
(such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
import shutil, os

# %%
def copyfolder_files(folder):
    for roots, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith(('.jpg','.pdf')):
             
                image_path = os.path.join(root,file)
                print('location:', image_path)
                new_path = os.path.join(r'C:\Users\Lenovo', 'my_test_folder')
                print(new_path)
                os.makedirs(new_path,exist_ok=True)
                shutil.copy(image_path,new_path)

# %%
copyfolder_files(r'C:\Users\Lenovo\Downloads')
# Out:
# location: C:\Users\Lenovo\anaconda3\envs\pythonendtoend2\tcl\tcl8.6\tzdata\America\1-Introduction To Deep Learning.pdf
# C:\Users\Lenovo\my_test_folder
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [176], in <cell line: 1>()
# ----> 1 copyfolder_files(r'C:\Users\Lenovo\Downloads')
#
# Input In [173], in copyfolder_files(folder)
#       9 print(new_path)
#      10 os.makedirs(new_path,exist_ok=True)
# ---> 11 shutil.copy(image_path,new_path)
#
# File ~\anaconda3\lib\shutil.py:426, in copy(src, dst, follow_symlinks)
#     424 if os.path.isdir(dst):
#     425     dst = os.path.join(dst, os.path.basename(src))
# --> 426 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     427 copymode(src, dst, follow_symlinks=follow_symlinks)
#     428 return dst
#
# File ~\anaconda3\lib\shutil.py:265, in copyfile(src, dst, follow_symlinks)
#     263 else:
#     264     try:
# ...

# %%
for root, dirs, files in os.walk(r'Lenovo'):
    print(root)
#     print(sum(getsize(join(root, name)) for name in files), end="")
#     print("bytes in", len(files), "non-directory files")
#     if 'CVS' in dirs:
#         dirs.remove('CVS')  # don't visit CVS

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Assignment\\Solved'

# %%
egg = "boil"
bacon ='Boil'
assert egg.casefold() != bacon.casefold(), "value"

# %%
assert False, "This statement throws a AssertionError everytime "

# %%
pip install PyPDF2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import PyPDF2 as pdf
pdfFileObj = open(r"C:\Users\Lenovo\Books\Hands_on_Machine_Learning_with_Scikit_Le.pdf", 'rb')
pdfReader = pdf.PdfFileReader(pdfFileObj)
pageObj = pdfReader.getPage(4)
pageObj.extract_text()
# Out:
# ' Table of Contents\n\n1.\n\n\nThe Machine Learning Landscape. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .   9\nWhat Is Machine Learning?                                                                                            10\nWhy Use Machine Learning?                                                                                          10\nTypes of Machine Learning Systems                                                                             13\nSupervised/Unsupervised Learning                                                                           14\nBatch and Online Learning                                                                                         21\nInstance-Based Versus Model-Based Learning                                                        24\nMain Challenges of Machine Learning                                                                         30\nInsufficient Quantity of Training Data     
# ...

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
img = Image.open('Radha-Krishna.jpg')
rgba = img.convert("RGBA")

# %%
rgba
# Out:
# <PIL.Image.Image image mode=RGBA size=169x300 at 0x1D51B32CF40>

# %%
reimg = img.resize((100,100))

# %%
img.crop((-85,-50,169,200))
# Out:
# <PIL.Image.Image image mode=RGB size=254x250 at 0x1D51C9FB670>

# %%
reimg.crop((0,50,50,100)).
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x1D51DD3FEE0>

# %%
reimg
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1D51C9FB760>

# %%
reimg.crop((50,50,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x1D51DE00670>

# %%
im = Image.new('RGBA', (200, 200), 'white')
draw = ImageDraw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [62], in <cell line: 2>()
#       1 im = Image.new('RGBA', (200, 200), 'white')
# ----> 2 draw = ImageDraw.Draw(im)
#
# NameError: name 'ImageDraw' is not defined

# %%
year_of_birth =  1978
year_list =[]
for i in range(0,5):
    year_list.append(year_of_birth+i)
print(year_list)
# Out:
# [1978, 1979, 1980, 1981, 1982]
